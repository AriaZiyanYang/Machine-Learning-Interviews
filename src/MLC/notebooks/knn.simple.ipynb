# %%
import numpy as np

class KNN:
    def __init__(self, k=3, distance='euclidean', p=2):
        self.k = k
        self.distance = distance
        self.p = p
        print(f"KNN initialized with k={k}, distance={distance}, p={p}")

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y
        print(f"Training data shape: X={X.shape}, y={y.shape}")
        print(f"Number of classes: {len(np.unique(y))}")

    # L2
    def euclidean_distance(self, x1, x2):
        dist = np.sqrt(np.sum((x1 - x2) ** 2))
        print(f"Euclidean distance: {dist:.4f}")
        return dist
    
    # L1
    def manhattan_distance(self, x1, x2):
        dist = np.sum(np.abs(x1 - x2))
        print(f"Manhattan distance: {dist:.4f}")
        return dist
    
    def minkowski_distance(self, x1, x2):
        dist = np.sum(np.abs(x1 - x2) ** self.p) ** (1/self.p)
        print(f"Minkowski distance (p={self.p}): {dist:.4f}")
        return dist
    
    def chebyshev_distance(self, x1, x2):
        dist = np.max(np.abs(x1 - x2))
        print(f"Chebyshev distance: {dist:.4f}")
        return dist
    
    def cosine_distance(self, x1, x2):
        dot_product = np.dot(x1, x2)
        norm_x1 = np.linalg.norm(x1)
        norm_x2 = np.linalg.norm(x2)
        if norm_x1 == 0 or norm_x2 == 0:
            print("Cosine distance: 1.0000 (zero vector)")
            return 1.0
        dist = 1 - (dot_product / (norm_x1 * norm_x2))
        print(f"Cosine distance: {dist:.4f}")
        return dist

    def predict(self, X):
        print(f"\nPredicting for {X.shape[0]} samples...")
        y_pred = [self._predict(x, i) for i, x in enumerate(X)]
        return np.array(y_pred)

    def _predict(self, x, sample_idx):
        print(f"\n--- Predicting sample {sample_idx + 1} ---")
        print(f"Test point: {x}")
        
        # Compute distances between x and all examples in the training set
        distances = []
        if self.distance == 'euclidean':
            distances = [self.euclidean_distance(x, x_train) for x_train in self.X_train]
        elif self.distance == 'manhattan':
            distances = [self.manhattan_distance(x, x_train) for x_train in self.X_train]
        elif self.distance == 'minkowski':
            distances = [self.minkowski_distance(x, x_train) for x_train in self.X_train]
        elif self.distance == 'chebyshev':
            distances = [self.chebyshev_distance(x, x_train) for x_train in self.X_train]
        elif self.distance == 'cosine':
            distances = [self.cosine_distance(x, x_train) for x_train in self.X_train]
        else:
            raise ValueError(f"Unsupported distance metric: {self.distance}")
        
        print(f"All distances: {[f'{d:.4f}' for d in distances[:5]]}...")  # 只显示前5个
        
        # Sort by distance and return indices of the first k neighbors
        k_indices = np.argsort(distances)[:self.k]
        print(f"K nearest neighbor indices: {k_indices}")
        
        # Extract the labels of the k nearest neighbor training samples
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        print(f"K nearest neighbor labels: {k_nearest_labels}")
        
        # Return the most common class label
        most_common = np.bincount(k_nearest_labels).argmax()
        print(f"Predicted label: {most_common}")
        
        return most_common

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 创建示例数据
X, y = make_classification(n_samples=100, n_features=2, n_redundant=0, 
                          n_informative=2, n_clusters_per_class=1, 
                          random_state=42)

# 分割数据
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                    random_state=42)

print(f"训练集大小: {X_train.shape[0]}")
print(f"测试集大小: {X_test.shape[0]}")

# 创建分类器
knn = KNN(k=3, distance='euclidean')

# 训练
knn.fit(X_train, y_train)

# 预测
predictions = knn.predict(X_test)

# 计算准确率
accuracy = accuracy_score(y_test, predictions)
print(f"\n准确率: {accuracy:.4f}")
# Out:
# 训练集大小: 70
# 测试集大小: 30
# KNN initialized with k=3, distance=euclidean, p=2
# Training data shape: X=(70, 2), y=(70,)
# Number of classes: 2
#
# Predicting for 30 samples...
#
# --- Predicting sample 1 ---
# Test point: [ 1.68674524 -0.35904111]
# Euclidean distance: 0.5856
# Euclidean distance: 0.9722
# Euclidean distance: 0.8565
# Euclidean distance: 2.1976
# Euclidean distance: 1.6894
# Euclidean distance: 1.3309
# Euclidean distance: 2.0973
# Euclidean distance: 2.6961
# Euclidean distance: 0.9012
# Euclidean distance: 0.8208
# Euclidean distance: 0.4537
# Euclidean distance: 1.5321
# Euclidean distance: 1.6590
# Euclidean distance: 1.6241
# Euclidean distance: 1.1747
# Euclidean distance: 1.9282
# Euclidean distance: 0.1805
# Euclidean distance: 1.6015
# Euclidean distance: 1.4137
# Euclidean distance: 2.5169
# Euclidean distance: 3.5444
# Euclidean distance: 1.4923
# Euclidean distance: 1.6854
# Euclidean distance: 1.2400
# Euclidean distance: 0.4329
# Euclidean distance: 1.9242
# Euclidean distance: 1.4773
# Euclidean distance: 1.7868
# Euclidean distance: 2.7274
# Euclidean distance: 1.7415
# Euclidean distance: 0.7645
# Euclidean distance: 1.6090
# Euclidean distance: 1.2613
# Euclidean distance: 1.6261
# Euclidean distance: 1.4184
# Euclidean distance: 1.4386
# Euclidean distance: 1.4992
# Euclidean distance: 0.1526
# Euclidean distance: 1.7305
# Euclidean distance: 1.6667
# Euclidean distance: 0.8209
# Euclidean distance: 1.6107
# Euclidean distance: 1.6542
# Euclidean distance: 0.4326
# Euclidean distance: 1.5039
# Euclidean distance: 1.4179
# Euclidean distance: 3.6474
# Euclidean distance: 2.4897
# Euclidean distance: 1.9036
# Euclidean distance: 0.1529
# Euclidean distance: 1.4797
# Euclidean distance: 2.1441
# Euclidean distance: 1.5776
# Euclidean distance: 0.2070
# Euclidean distance: 1.4212
# Euclidean distance: 0.9796
# Euclidean distance: 3.4917
# Euclidean distance: 2.9883
# Euclidean distance: 1.5356
# Euclidean distance: 1.2362
# Euclidean distance: 1.6375
# Euclidean distance: 2.8251
# Euclidean distance: 1.7359
# Euclidean distance: 2.5728
# Euclidean distance: 0.7430
# Euclidean distance: 1.5447
# Euclidean distance: 1.7751
# Euclidean distance: 3.4847
# Euclidean distance: 0.4191
# Euclidean distance: 1.6204
# All distances: ['0.5856', '0.9722', '0.8565', '2.1976', '1.6894']...
# K nearest neighbor indices: [37 49 16]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 2 ---
# Test point: [ 0.87717639 -1.15469945]
# Euclidean distance: 0.5541
# Euclidean distance: 0.1638
# Euclidean distance: 0.2787
# Euclidean distance: 1.0713
# Euclidean distance: 1.5634
# Euclidean distance: 0.2443
# Euclidean distance: 3.0355
# Euclidean distance: 3.7102
# Euclidean distance: 0.2396
# Euclidean distance: 0.3374
# Euclidean distance: 0.7015
# Euclidean distance: 0.3971
# Euclidean distance: 1.5489
# Euclidean distance: 0.4936
# Euclidean distance: 0.0397
# Euclidean distance: 2.8484
# Euclidean distance: 1.2636
# Euclidean distance: 1.5895
# Euclidean distance: 1.9010
# Euclidean distance: 3.5217
# Euclidean distance: 4.6143
# Euclidean distance: 0.3626
# Euclidean distance: 1.5758
# Euclidean distance: 0.1180
# Euclidean distance: 0.7166
# Euclidean distance: 1.4926
# Euclidean distance: 0.3564
# Euclidean distance: 0.6527
# Euclidean distance: 3.7372
# Euclidean distance: 1.5407
# Euclidean distance: 0.3897
# Euclidean distance: 2.2749
# Euclidean distance: 0.1262
# Euclidean distance: 2.3843
# Euclidean distance: 1.8508
# Euclidean distance: 1.9075
# Euclidean distance: 0.3899
# Euclidean distance: 1.2637
# Euclidean distance: 2.5676
# Euclidean distance: 0.5335
# Euclidean distance: 0.3142
# Euclidean distance: 1.4830
# Euclidean distance: 1.4709
# Euclidean distance: 0.7116
# Euclidean distance: 1.9227
# Euclidean distance: 1.8518
# Euclidean distance: 4.7223
# Euclidean distance: 3.4938
# Euclidean distance: 2.7831
# Euclidean distance: 1.2860
# Euclidean distance: 2.1362
# Euclidean distance: 3.0919
# Euclidean distance: 2.2702
# Euclidean distance: 1.2859
# Euclidean distance: 0.2878
# Euclidean distance: 0.1773
# Euclidean distance: 4.5635
# Euclidean distance: 4.0209
# Euclidean distance: 1.7972
# Euclidean distance: 0.1462
# Euclidean distance: 0.5027
# Euclidean distance: 1.6913
# Euclidean distance: 0.6152
# Euclidean distance: 1.7858
# Euclidean distance: 0.3922
# Euclidean distance: 2.0004
# Euclidean distance: 0.6418
# Euclidean distance: 4.5578
# Euclidean distance: 0.7182
# Euclidean distance: 2.3784
# All distances: ['0.5541', '0.1638', '0.2787', '1.0713', '1.5634']...
# K nearest neighbor indices: [14 23 32]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 3 ---
# Test point: [0.59137345 0.65689322]
# Euclidean distance: 1.5305
# Euclidean distance: 1.7579
# Euclidean distance: 1.6893
# Euclidean distance: 2.4879
# Euclidean distance: 0.6793
# Euclidean distance: 1.8302
# Euclidean distance: 1.6249
# Euclidean distance: 2.3645
# Euclidean distance: 1.6675
# Euclidean distance: 1.5755
# Euclidean distance: 1.6400
# Euclidean distance: 2.0964
# Euclidean distance: 0.6541
# Euclidean distance: 2.0988
# Euclidean distance: 1.8597
# Euclidean distance: 1.4439
# Euclidean distance: 1.6370
# Euclidean distance: 0.5152
# Euclidean distance: 0.2299
# Euclidean distance: 2.1773
# Euclidean distance: 3.3493
# Euclidean distance: 2.0100
# Euclidean distance: 0.6565
# Euclidean distance: 1.8518
# Euclidean distance: 1.4485
# Euclidean distance: 1.1480
# Euclidean distance: 1.9676
# Euclidean distance: 2.2455
# Euclidean distance: 2.3774
# Euclidean distance: 0.7891
# Euclidean distance: 1.7339
# Euclidean distance: 0.6409
# Euclidean distance: 1.9108
# Euclidean distance: 0.8433
# Euclidean distance: 0.1451
# Euclidean distance: 0.2015
# Euclidean distance: 1.9483
# Euclidean distance: 1.5910
# Euclidean distance: 1.0902
# Euclidean distance: 2.1483
# Euclidean distance: 1.6680
# Euclidean distance: 0.6753
# Euclidean distance: 0.7529
# Euclidean distance: 1.6026
# Euclidean distance: 0.1341
# Euclidean distance: 0.1473
# Euclidean distance: 3.4681
# Euclidean distance: 2.1516
# Euclidean distance: 1.3182
# Euclidean distance: 1.5342
# Euclidean distance: 0.5547
# Euclidean distance: 1.6898
# Euclidean distance: 0.6763
# Euclidean distance: 1.6565
# Euclidean distance: 2.0400
# Euclidean distance: 1.8145
# Euclidean distance: 3.3091
# Euclidean distance: 2.6902
# Euclidean distance: 0.1188
# Euclidean distance: 1.8059
# Euclidean distance: 2.1793
# Euclidean distance: 3.0839
# Euclidean distance: 2.1257
# Euclidean distance: 2.0097
# Euclidean distance: 1.6398
# Euclidean distance: 0.2179
# Euclidean distance: 2.2262
# Euclidean distance: 3.3091
# Euclidean distance: 1.5658
# Euclidean distance: 0.8393
# All distances: ['1.5305', '1.7579', '1.6893', '2.4879', '0.6793']...
# K nearest neighbor indices: [58 44 34]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 4 ---
# Test point: [-0.77719676 -0.63604713]
# Euclidean distance: 2.0145
# Euclidean distance: 1.8296
# Euclidean distance: 1.8829
# Euclidean distance: 1.3598
# Euclidean distance: 1.2035
# Euclidean distance: 1.5094
# Euclidean distance: 3.5072
# Euclidean distance: 4.2472
# Euclidean distance: 1.8178
# Euclidean distance: 1.8235
# Euclidean distance: 2.2252
# Euclidean distance: 1.5948
# Euclidean distance: 1.2289
# Euclidean distance: 1.4859
# Euclidean distance: 1.7181
# Euclidean distance: 3.3245
# Euclidean distance: 2.6576
# Euclidean distance: 1.3677
# Euclidean distance: 2.0992
# Euclidean distance: 4.0595
# Euclidean distance: 5.2317
# Euclidean distance: 1.5292
# Euclidean distance: 1.2265
# Euclidean distance: 1.6363
# Euclidean distance: 2.1004
# Euclidean distance: 0.7354
# Euclidean distance: 1.4945
# Euclidean distance: 1.4932
# Euclidean distance: 4.2601
# Euclidean distance: 1.0937
# Euclidean distance: 2.0188
# Euclidean distance: 2.5233
# Euclidean distance: 1.6788
# Euclidean distance: 2.7252
# Euclidean distance: 2.0097
# Euclidean distance: 2.0772
# Euclidean distance: 1.4450
# Euclidean distance: 2.6318
# Euclidean distance: 2.9715
# Euclidean distance: 1.5019
# Euclidean distance: 1.8993
# Euclidean distance: 1.2140
# Euclidean distance: 1.1353
# Euclidean distance: 2.2095
# Euclidean distance: 2.0162
# Euclidean distance: 2.0120
# Euclidean distance: 5.3504
# Euclidean distance: 4.0336
# Euclidean distance: 3.2008
# Euclidean distance: 2.6151
# Euclidean distance: 2.4328
# Euclidean distance: 3.5721
# Euclidean distance: 2.5588
# Euclidean distance: 2.6843
# Euclidean distance: 1.6527
# Euclidean distance: 1.8810
# Euclidean distance: 5.1911
# Euclidean distance: 4.5729
# Euclidean distance: 1.7680
# Euclidean distance: 1.5917
# Euclidean distance: 1.5819
# Euclidean distance: 1.6703
# Euclidean distance: 1.3842
# Euclidean distance: 0.1279
# Euclidean distance: 1.9514
# Euclidean distance: 2.0955
# Euclidean distance: 1.4793
# Euclidean distance: 5.1909
# Euclidean distance: 2.1903
# Euclidean distance: 2.7210
# All distances: ['2.0145', '1.8296', '1.8829', '1.3598', '1.2035']...
# K nearest neighbor indices: [63 25 29]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 5 ---
# Test point: [ 1.29021194 -0.76408578]
# Euclidean distance: 0.0640
# Euclidean distance: 0.4054
# Euclidean distance: 0.2899
# Euclidean distance: 1.6350
# Euclidean distance: 1.5364
# Euclidean distance: 0.7735
# Euclidean distance: 2.5518
# Euclidean distance: 3.1971
# Euclidean distance: 0.3382
# Euclidean distance: 0.2729
# Euclidean distance: 0.1566
# Euclidean distance: 0.9654
# Euclidean distance: 1.5122
# Euclidean distance: 1.0594
# Euclidean distance: 0.6081
# Euclidean distance: 2.3707
# Euclidean distance: 0.6990
# Euclidean distance: 1.5021
# Euclidean distance: 1.5855
# Euclidean distance: 3.0120
# Euclidean distance: 4.0778
# Euclidean distance: 0.9276
# Euclidean distance: 1.5406
# Euclidean distance: 0.6753
# Euclidean distance: 0.1738
# Euclidean distance: 1.6361
# Euclidean distance: 0.9147
# Euclidean distance: 1.2208
# Euclidean distance: 3.2261
# Euclidean distance: 1.5540
# Euclidean distance: 0.2106
# Euclidean distance: 1.8950
# Euclidean distance: 0.6946
# Euclidean distance: 1.9676
# Euclidean distance: 1.5577
# Euclidean distance: 1.6007
# Euclidean distance: 0.9396
# Euclidean distance: 0.6965
# Euclidean distance: 2.1212
# Euclidean distance: 1.1010
# Euclidean distance: 0.2546
# Euclidean distance: 1.4514
# Euclidean distance: 1.4696
# Euclidean distance: 0.1517
# Euclidean distance: 1.6398
# Euclidean distance: 1.5581
# Euclidean distance: 4.1836
# Euclidean distance: 2.9843
# Euclidean distance: 2.3219
# Euclidean distance: 0.7175
# Euclidean distance: 1.7559
# Euclidean distance: 2.6046
# Euclidean distance: 1.8786
# Euclidean distance: 0.7223
# Euclidean distance: 0.8544
# Euclidean distance: 0.4153
# Euclidean distance: 4.0261
# Euclidean distance: 3.5004
# Euclidean distance: 1.5826
# Euclidean distance: 0.6755
# Euclidean distance: 1.0707
# Euclidean distance: 2.2594
# Euclidean distance: 1.1745
# Euclidean distance: 2.1489
# Euclidean distance: 0.1764
# Euclidean distance: 1.7042
# Euclidean distance: 1.2094
# Euclidean distance: 4.0198
# Euclidean distance: 0.1508
# Euclidean distance: 1.9617
# All distances: ['0.0640', '0.4054', '0.2899', '1.6350', '1.5364']...
# K nearest neighbor indices: [ 0 68 43]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 6 ---
# Test point: [ 1.85766106 -0.40530133]
# Euclidean distance: 0.7030
# Euclidean distance: 1.0703
# Euclidean distance: 0.9578
# Euclidean distance: 2.3045
# Euclidean distance: 1.8660
# Euclidean distance: 1.4448
# Euclidean distance: 2.1407
# Euclidean distance: 2.7060
# Euclidean distance: 1.0094
# Euclidean distance: 0.9395
# Euclidean distance: 0.5331
# Euclidean distance: 1.6279
# Euclidean distance: 1.8356
# Euclidean distance: 1.7274
# Euclidean distance: 1.2731
# Euclidean distance: 1.9798
# Euclidean distance: 0.0373
# Euclidean distance: 1.7766
# Euclidean distance: 1.5600
# Euclidean distance: 2.5319
# Euclidean distance: 3.5243
# Euclidean distance: 1.5959
# Euclidean distance: 1.8619
# Euclidean distance: 1.3446
# Euclidean distance: 0.5670
# Euclidean distance: 2.0993
# Euclidean distance: 1.5849
# Euclidean distance: 1.8862
# Euclidean distance: 2.7388
# Euclidean distance: 1.9186
# Euclidean distance: 0.8493
# Euclidean distance: 1.7255
# Euclidean distance: 1.3593
# Euclidean distance: 1.7247
# Euclidean distance: 1.5705
# Euclidean distance: 1.5864
# Euclidean distance: 1.6108
# Euclidean distance: 0.0754
# Euclidean distance: 1.8088
# Euclidean distance: 1.7675
# Euclidean distance: 0.9237
# Euclidean distance: 1.7876
# Euclidean distance: 1.8313
# Euclidean distance: 0.5230
# Euclidean distance: 1.6555
# Euclidean distance: 1.5699
# Euclidean distance: 3.6242
# Euclidean distance: 2.5053
# Euclidean distance: 1.9675
# Euclidean distance: 0.1407
# Euclidean distance: 1.6011
# Euclidean distance: 2.1838
# Euclidean distance: 1.6902
# Euclidean distance: 0.0525
# Euclidean distance: 1.5148
# Euclidean distance: 1.0684
# Euclidean distance: 3.4708
# Euclidean distance: 2.9886
# Euclidean distance: 1.6994
# Euclidean distance: 1.3467
# Euclidean distance: 1.7319
# Euclidean distance: 2.9240
# Euclidean distance: 1.8450
# Euclidean distance: 2.7361
# Euclidean distance: 0.8459
# Euclidean distance: 1.6916
# Euclidean distance: 1.8757
# Euclidean distance: 3.4630
# Euclidean distance: 0.5209
# Euclidean distance: 1.7193
# All distances: ['0.7030', '1.0703', '0.9578', '2.3045', '1.8660']...
# K nearest neighbor indices: [16 53 37]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 7 ---
# Test point: [ 1.88782031 -0.36699364]
# Euclidean distance: 0.7478
# Euclidean distance: 1.1176
# Euclidean distance: 1.0047
# Euclidean distance: 2.3514
# Euclidean distance: 1.8828
# Euclidean distance: 1.4908
# Euclidean distance: 2.1033
# Euclidean distance: 2.6631
# Euclidean distance: 1.0557
# Euclidean distance: 0.9845
# Euclidean distance: 0.5808
# Euclidean distance: 1.6756
# Euclidean distance: 1.8520
# Euclidean distance: 1.7746
# Euclidean distance: 1.3204
# Euclidean distance: 1.9441
# Euclidean distance: 0.0210
# Euclidean distance: 1.7898
# Euclidean distance: 1.5529
# Euclidean distance: 2.4898
# Euclidean distance: 3.4780
# Euclidean distance: 1.6430
# Euclidean distance: 1.8780
# Euclidean distance: 1.3914
# Euclidean distance: 0.6088
# Euclidean distance: 2.1250
# Euclidean distance: 1.6316
# Euclidean distance: 1.9337
# Euclidean distance: 2.6961
# Euclidean distance: 1.9376
# Euclidean distance: 0.8972
# Euclidean distance: 1.7066
# Euclidean distance: 1.4067
# Euclidean distance: 1.7004
# Euclidean distance: 1.5661
# Euclidean distance: 1.5800
# Euclidean distance: 1.6571
# Euclidean distance: 0.0612
# Euclidean distance: 1.7791
# Euclidean distance: 1.8148
# Euclidean distance: 0.9704
# Euclidean distance: 1.8052
# Euclidean distance: 1.8505
# Euclidean distance: 0.5700
# Euclidean distance: 1.6507
# Euclidean distance: 1.5655
# Euclidean distance: 3.5775
# Euclidean distance: 2.4632
# Euclidean distance: 1.9344
# Euclidean distance: 0.1212
# Euclidean distance: 1.5840
# Euclidean distance: 2.1457
# Euclidean distance: 1.6701
# Euclidean distance: 0.0057
# Euclidean distance: 1.5625
# Euclidean distance: 1.1162
# Euclidean distance: 3.4243
# Euclidean distance: 2.9444
# Euclidean distance: 1.7018
# Euclidean distance: 1.3930
# Euclidean distance: 1.7797
# Euclidean distance: 2.9717
# Euclidean distance: 1.8916
# Euclidean distance: 2.7709
# Euclidean distance: 0.8925
# Euclidean distance: 1.6846
# Euclidean distance: 1.9231
# Euclidean distance: 3.4165
# Euclidean distance: 0.5668
# Euclidean distance: 1.6950
# All distances: ['0.7478', '1.1176', '1.0047', '2.3514', '1.8828']...
# K nearest neighbor indices: [53 16 37]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 8 ---
# Test point: [0.64569333 0.69203257]
# Euclidean distance: 1.5409
# Euclidean distance: 1.7803
# Euclidean distance: 1.7084
# Euclidean distance: 2.5355
# Euclidean distance: 0.7432
# Euclidean distance: 1.8649
# Euclidean distance: 1.5610
# Euclidean distance: 2.3008
# Euclidean distance: 1.6889
# Euclidean distance: 1.5952
# Euclidean distance: 1.6430
# Euclidean distance: 2.1320
# Euclidean distance: 0.7176
# Euclidean distance: 2.1376
# Euclidean distance: 1.8878
# Euclidean distance: 1.3796
# Euclidean distance: 1.6179
# Euclidean distance: 0.5787
# Euclidean distance: 0.1667
# Euclidean distance: 2.1134
# Euclidean distance: 3.2854
# Euclidean distance: 2.0463
# Euclidean distance: 0.7205
# Euclidean distance: 1.8826
# Euclidean distance: 1.4528
# Euclidean distance: 1.2114
# Euclidean distance: 2.0044
# Euclidean distance: 2.2861
# Euclidean distance: 2.3138
# Euclidean distance: 0.8529
# Euclidean distance: 1.7483
# Euclidean distance: 0.5780
# Euclidean distance: 1.9410
# Euclidean distance: 0.7792
# Euclidean distance: 0.0869
# Euclidean distance: 0.1372
# Euclidean distance: 1.9864
# Euclidean distance: 1.5715
# Euclidean distance: 1.0260
# Euclidean distance: 2.1873
# Euclidean distance: 1.6861
# Euclidean distance: 0.7375
# Euclidean distance: 0.8153
# Euclidean distance: 1.6054
# Euclidean distance: 0.0740
# Euclidean distance: 0.0889
# Euclidean distance: 3.4042
# Euclidean distance: 2.0876
# Euclidean distance: 1.2544
# Euclidean distance: 1.5135
# Euclidean distance: 0.4901
# Euclidean distance: 1.6259
# Euclidean distance: 0.6124
# Euclidean distance: 1.6367
# Euclidean distance: 2.0730
# Euclidean distance: 1.8359
# Euclidean distance: 3.2451
# Euclidean distance: 2.6266
# Euclidean distance: 0.1834
# Euclidean distance: 1.8377
# Euclidean distance: 2.2165
# Euclidean distance: 3.1349
# Euclidean distance: 2.1676
# Euclidean distance: 2.0732
# Euclidean distance: 1.6552
# Euclidean distance: 0.1608
# Euclidean distance: 2.2669
# Euclidean distance: 3.2450
# Euclidean distance: 1.5686
# Euclidean distance: 0.7751
# All distances: ['1.5409', '1.7803', '1.7084', '2.5355', '0.7432']...
# K nearest neighbor indices: [44 34 45]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 9 ---
# Test point: [ 0.63944087 -1.23395477]
# Euclidean distance: 0.7791
# Euclidean distance: 0.4081
# Euclidean distance: 0.5161
# Euclidean distance: 0.8330
# Euclidean distance: 1.5322
# Euclidean distance: 0.0614
# Euclidean distance: 3.1902
# Euclidean distance: 3.8808
# Euclidean distance: 0.4645
# Euclidean distance: 0.5461
# Euclidean distance: 0.9436
# Euclidean distance: 0.2092
# Euclidean distance: 1.5227
# Euclidean distance: 0.2636
# Euclidean distance: 0.2172
# Euclidean distance: 3.0007
# Euclidean distance: 1.5016
# Euclidean distance: 1.5840
# Euclidean distance: 1.9857
# Euclidean distance: 3.6906
# Euclidean distance: 4.8003
# Euclidean distance: 0.1360
# Euclidean distance: 1.5477
# Euclidean distance: 0.1328
# Euclidean distance: 0.9366
# Euclidean distance: 1.3876
# Euclidean distance: 0.1127
# Euclidean distance: 0.4309
# Euclidean distance: 3.9063
# Euclidean distance: 1.4925
# Euclidean distance: 0.6373
# Euclidean distance: 2.3823
# Euclidean distance: 0.1487
# Euclidean distance: 2.5082
# Euclidean distance: 1.9266
# Euclidean distance: 1.9880
# Euclidean distance: 0.1397
# Euclidean distance: 1.4988
# Euclidean distance: 2.7048
# Euclidean distance: 0.3105
# Euclidean distance: 0.5498
# Euclidean distance: 1.4576
# Euclidean distance: 1.4324
# Euclidean distance: 0.9505
# Euclidean distance: 1.9922
# Euclidean distance: 1.9279
# Euclidean distance: 4.9101
# Euclidean distance: 3.6626
# Euclidean distance: 2.9265
# Euclidean distance: 1.5170
# Euclidean distance: 2.2458
# Euclidean distance: 3.2485
# Euclidean distance: 2.3832
# Euclidean distance: 1.5246
# Euclidean distance: 0.1578
# Euclidean distance: 0.4279
# Euclidean distance: 4.7504
# Euclidean distance: 4.1958
# Euclidean distance: 1.8400
# Euclidean distance: 0.1289
# Euclidean distance: 0.3066
# Euclidean distance: 1.4630
# Euclidean distance: 0.3718
# Euclidean distance: 1.5790
# Euclidean distance: 0.6275
# Euclidean distance: 2.0740
# Euclidean distance: 0.4167
# Euclidean distance: 4.7453
# Euclidean distance: 0.9535
# Euclidean distance: 2.5024
# All distances: ['0.7791', '0.4081', '0.5161', '0.8330', '1.5322']...
# K nearest neighbor indices: [ 5 26 59]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 10 ---
# Test point: [ 1.22831184 -0.75717844]
# Euclidean distance: 0.0264
# Euclidean distance: 0.3699
# Euclidean distance: 0.2535
# Euclidean distance: 1.5906
# Euclidean distance: 1.4842
# Euclidean distance: 0.7256
# Euclidean distance: 2.5583
# Euclidean distance: 3.2113
# Euclidean distance: 0.2942
# Euclidean distance: 0.2186
# Euclidean distance: 0.2175
# Euclidean distance: 0.9272
# Euclidean distance: 1.4604
# Euclidean distance: 1.0170
# Euclidean distance: 0.5701
# Euclidean distance: 2.3757
# Euclidean distance: 0.7473
# Euclidean distance: 1.4538
# Euclidean distance: 1.5609
# Euclidean distance: 3.0252
# Euclidean distance: 4.0991
# Euclidean distance: 0.8852
# Euclidean distance: 1.4888
# Euclidean distance: 0.6329
# Euclidean distance: 0.1890
# Euclidean distance: 1.5762
# Euclidean distance: 0.8702
# Euclidean distance: 1.1803
# Euclidean distance: 3.2398
# Euclidean distance: 1.4995
# Euclidean distance: 0.2041
# Euclidean distance: 1.8809
# Euclidean distance: 0.6564
# Euclidean distance: 1.9599
# Euclidean distance: 1.5301
# Euclidean distance: 1.5750
# Euclidean distance: 0.8931
# Euclidean distance: 0.7421
# Euclidean distance: 2.1193
# Euclidean distance: 1.0599
# Euclidean distance: 0.2176
# Euclidean distance: 1.3991
# Euclidean distance: 1.4156
# Euclidean distance: 0.2087
# Euclidean distance: 1.6113
# Euclidean distance: 1.5306
# Euclidean distance: 4.2057
# Euclidean distance: 2.9974
# Euclidean distance: 2.3233
# Euclidean distance: 0.7593
# Euclidean distance: 1.7415
# Euclidean distance: 2.6120
# Euclidean distance: 1.8664
# Euclidean distance: 0.7712
# Euclidean distance: 0.8180
# Euclidean distance: 0.3882
# Euclidean distance: 4.0477
# Euclidean distance: 3.5168
# Euclidean distance: 1.5461
# Euclidean distance: 0.6295
# Euclidean distance: 1.0330
# Euclidean distance: 2.2182
# Euclidean distance: 1.1292
# Euclidean distance: 2.0870
# Euclidean distance: 0.1426
# Euclidean distance: 1.6776
# Euclidean distance: 1.1682
# Euclidean distance: 4.0416
# Euclidean distance: 0.2014
# Euclidean distance: 1.9540
# All distances: ['0.0264', '0.3699', '0.2535', '1.5906', '1.4842']...
# K nearest neighbor indices: [ 0 64 24]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 11 ---
# Test point: [0.57885884 0.56599415]
# Euclidean distance: 1.4541
# Euclidean distance: 1.6728
# Euclidean distance: 1.6063
# Euclidean distance: 2.3967
# Euclidean distance: 0.6114
# Euclidean distance: 1.7396
# Euclidean distance: 1.6956
# Euclidean distance: 2.4360
# Euclidean distance: 1.5831
# Euclidean distance: 1.4923
# Euclidean distance: 1.5700
# Euclidean distance: 2.0056
# Euclidean distance: 0.5842
# Euclidean distance: 2.0074
# Euclidean distance: 1.7716
# Euclidean distance: 1.5123
# Euclidean distance: 1.5918
# Euclidean distance: 0.4459
# Euclidean distance: 0.2874
# Euclidean distance: 2.2477
# Euclidean distance: 3.4200
# Euclidean distance: 1.9190
# Euclidean distance: 0.5894
# Euclidean distance: 1.7626
# Euclidean distance: 1.3775
# Euclidean distance: 1.0767
# Euclidean distance: 1.8765
# Euclidean distance: 2.1538
# Euclidean distance: 2.4498
# Euclidean distance: 0.7205
# Euclidean distance: 1.6542
# Euclidean distance: 0.7167
# Euclidean distance: 1.8218
# Euclidean distance: 0.9137
# Euclidean distance: 0.1977
# Euclidean distance: 0.2653
# Euclidean distance: 1.8570
# Euclidean distance: 1.5463
# Euclidean distance: 1.1595
# Euclidean distance: 2.0568
# Euclidean distance: 1.5858
# Euclidean distance: 0.5998
# Euclidean distance: 0.6782
# Euclidean distance: 1.5329
# Euclidean distance: 0.2167
# Euclidean distance: 0.2001
# Euclidean distance: 3.5386
# Euclidean distance: 2.2217
# Euclidean distance: 1.3897
# Euclidean distance: 1.4913
# Euclidean distance: 0.6207
# Euclidean distance: 1.7605
# Euclidean distance: 0.7483
# Euclidean distance: 1.6121
# Euclidean distance: 1.9500
# Euclidean distance: 1.7300
# Euclidean distance: 3.3791
# Euclidean distance: 2.7622
# Euclidean distance: 0.0976
# Euclidean distance: 1.7164
# Euclidean distance: 2.0881
# Euclidean distance: 2.9938
# Euclidean distance: 2.0339
# Euclidean distance: 1.9385
# Euclidean distance: 1.5595
# Euclidean distance: 0.3033
# Euclidean distance: 2.1345
# Euclidean distance: 3.3788
# Euclidean distance: 1.4962
# Euclidean distance: 0.9094
# All distances: ['1.4541', '1.6728', '1.6063', '2.3967', '0.6114']...
# K nearest neighbor indices: [58 34 45]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 12 ---
# Test point: [ 0.76916909 -1.0609667 ]
# Euclidean distance: 0.5705
# Euclidean distance: 0.2356
# Euclidean distance: 0.3241
# Euclidean distance: 1.0439
# Euclidean distance: 1.4288
# Euclidean distance: 0.1758
# Euclidean distance: 2.9823
# Euclidean distance: 3.6688
# Euclidean distance: 0.2644
# Euclidean distance: 0.3345
# Euclidean distance: 0.7471
# Euclidean distance: 0.4144
# Euclidean distance: 1.4153
# Euclidean distance: 0.4797
# Euclidean distance: 0.1482
# Euclidean distance: 2.7934
# Euclidean distance: 1.2976
# Euclidean distance: 1.4610
# Euclidean distance: 1.8062
# Euclidean distance: 3.4789
# Euclidean distance: 4.5855
# Euclidean distance: 0.3515
# Euclidean distance: 1.4419
# Euclidean distance: 0.1261
# Euclidean distance: 0.7246
# Euclidean distance: 1.3496
# Euclidean distance: 0.3277
# Euclidean distance: 0.6471
# Euclidean distance: 3.6947
# Euclidean distance: 1.4030
# Euclidean distance: 0.4572
# Euclidean distance: 2.1921
# Euclidean distance: 0.1838
# Euclidean distance: 2.3110
# Euclidean distance: 1.7518
# Euclidean distance: 1.8107
# Euclidean distance: 0.3447
# Euclidean distance: 1.2925
# Euclidean distance: 2.5025
# Euclidean distance: 0.5267
# Euclidean distance: 0.3540
# Euclidean distance: 1.3495
# Euclidean distance: 1.3347
# Euclidean distance: 0.7502
# Euclidean distance: 1.8210
# Euclidean distance: 1.7529
# Euclidean distance: 4.6950
# Euclidean distance: 3.4510
# Euclidean distance: 2.7221
# Euclidean distance: 1.3080
# Euclidean distance: 2.0545
# Euclidean distance: 3.0401
# Euclidean distance: 2.1905
# Euclidean distance: 1.3213
# Euclidean distance: 0.3271
# Euclidean distance: 0.2793
# Euclidean distance: 4.5354
# Euclidean distance: 3.9829
# Euclidean distance: 1.6844
# Euclidean distance: 0.0909
# Euclidean distance: 0.5174
# Euclidean distance: 1.6772
# Euclidean distance: 0.5821
# Euclidean distance: 1.6601
# Euclidean distance: 0.4288
# Euclidean distance: 1.9006
# Euclidean distance: 0.6329
# Euclidean distance: 4.5303
# Euclidean distance: 0.7498
# Euclidean distance: 2.3051
# All distances: ['0.5705', '0.2356', '0.3241', '1.0439', '1.4288']...
# K nearest neighbor indices: [59 23 14]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 13 ---
# Test point: [ 0.73375167 -1.24567514]
# Euclidean distance: 0.7179
# Euclidean distance: 0.3331
# Euclidean distance: 0.4463
# Euclidean distance: 0.9015
# Euclidean distance: 1.5791
# Euclidean distance: 0.1239
# Euclidean distance: 3.1679
# Euclidean distance: 3.8513
# Euclidean distance: 0.4013
# Euclidean distance: 0.4918
# Euclidean distance: 0.8711
# Euclidean distance: 0.2352
# Euclidean distance: 1.5679
# Euclidean distance: 0.3241
# Euclidean distance: 0.1322
# Euclidean distance: 2.9794
# Euclidean distance: 1.4326
# Euclidean distance: 1.6224
# Euclidean distance: 1.9918
# Euclidean distance: 3.6618
# Euclidean distance: 4.7633
# Euclidean distance: 0.1928
# Euclidean distance: 1.5936
# Euclidean distance: 0.0659
# Euclidean distance: 0.8788
# Euclidean distance: 1.4571
# Euclidean distance: 0.1886
# Euclidean distance: 0.4852
# Euclidean distance: 3.8775
# Euclidean distance: 1.5449
# Euclidean distance: 0.5594
# Euclidean distance: 2.3799
# Euclidean distance: 0.0541
# Euclidean distance: 2.4990
# Euclidean distance: 1.9361
# Euclidean distance: 1.9958
# Euclidean distance: 0.2267
# Euclidean distance: 1.4320
# Euclidean distance: 2.6900
# Euclidean distance: 0.3651
# Euclidean distance: 0.4813
# Euclidean distance: 1.5023
# Euclidean distance: 1.4814
# Euclidean distance: 0.8806
# Euclidean distance: 2.0042
# Euclidean distance: 1.9373
# Euclidean distance: 4.8722
# Euclidean distance: 3.6339
# Euclidean distance: 2.9092
# Euclidean distance: 1.4531
# Euclidean distance: 2.2423
# Euclidean distance: 3.2254
# Euclidean distance: 2.3785
# Euclidean distance: 1.4551
# Euclidean distance: 0.1392
# Euclidean distance: 0.3445
# Euclidean distance: 4.7129
# Euclidean distance: 4.1643
# Euclidean distance: 1.8618
# Euclidean distance: 0.1021
# Euclidean distance: 0.3409
# Euclidean distance: 1.5236
# Euclidean distance: 0.4457
# Euclidean distance: 1.6722
# Euclidean distance: 0.5595
# Euclidean distance: 2.0846
# Euclidean distance: 0.4735
# Euclidean distance: 4.7076
# Euclidean distance: 0.8862
# Euclidean distance: 2.4932
# All distances: ['0.7179', '0.3331', '0.4463', '0.9015', '1.5791']...
# K nearest neighbor indices: [32 23 59]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 14 ---
# Test point: [ 0.87971932 -1.17756932]
# Euclidean distance: 0.5701
# Euclidean distance: 0.1773
# Euclidean distance: 0.2933
# Euclidean distance: 1.0607
# Euclidean distance: 1.5845
# Euclidean distance: 0.2462
# Euclidean distance: 3.0565
# Euclidean distance: 3.7303
# Euclidean distance: 0.2575
# Euclidean distance: 0.3568
# Euclidean distance: 0.7132
# Euclidean distance: 0.3829
# Euclidean distance: 1.5702
# Euclidean distance: 0.4830
# Euclidean distance: 0.0296
# Euclidean distance: 2.8695
# Euclidean distance: 1.2760
# Euclidean distance: 1.6115
# Euclidean distance: 1.9240
# Euclidean distance: 3.5419
# Euclidean distance: 4.6332
# Euclidean distance: 0.3528
# Euclidean distance: 1.5970
# Euclidean distance: 0.1165
# Euclidean distance: 0.7331
# Euclidean distance: 1.5099
# Euclidean distance: 0.3494
# Euclidean distance: 0.6401
# Euclidean distance: 3.7573
# Euclidean distance: 1.5611
# Euclidean distance: 0.3994
# Euclidean distance: 2.2975
# Euclidean distance: 0.1133
# Euclidean distance: 2.4066
# Euclidean distance: 1.8738
# Euclidean distance: 1.9304
# Euclidean distance: 0.3850
# Euclidean distance: 1.2768
# Euclidean distance: 2.5894
# Euclidean distance: 0.5216
# Euclidean distance: 0.3291
# Euclidean distance: 1.5043
# Euclidean distance: 1.4916
# Euclidean distance: 0.7242
# Euclidean distance: 1.9457
# Euclidean distance: 1.8748
# Euclidean distance: 4.7411
# Euclidean distance: 3.5140
# Euclidean distance: 2.8046
# Euclidean distance: 1.3000
# Euclidean distance: 2.1588
# Euclidean distance: 3.1128
# Euclidean distance: 2.2927
# Euclidean distance: 1.2980
# Euclidean distance: 0.2720
# Euclidean distance: 0.1834
# Euclidean distance: 4.5823
# Euclidean distance: 4.0407
# Euclidean distance: 1.8201
# Euclidean distance: 0.1521
# Euclidean distance: 0.4881
# Euclidean distance: 1.6784
# Euclidean distance: 0.6067
# Euclidean distance: 1.7938
# Euclidean distance: 0.4067
# Euclidean distance: 2.0234
# Euclidean distance: 0.6297
# Euclidean distance: 4.5766
# Euclidean distance: 0.7318
# Euclidean distance: 2.4007
# All distances: ['0.5701', '0.1773', '0.2933', '1.0607', '1.5845']...
# K nearest neighbor indices: [14 32 23]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 15 ---
# Test point: [0.24802757 0.27894398]
# Euclidean distance: 1.4126
# Euclidean distance: 1.5307
# Euclidean distance: 1.4917
# Euclidean distance: 2.0526
# Euclidean distance: 0.1768
# Euclidean distance: 1.5021
# Euclidean distance: 2.1333
# Euclidean distance: 2.8735
# Euclidean distance: 1.4528
# Euclidean distance: 1.3796
# Euclidean distance: 1.5743
# Euclidean distance: 1.7542
# Euclidean distance: 0.1473
# Euclidean distance: 1.7323
# Euclidean distance: 1.5828
# Euclidean distance: 1.9503
# Euclidean distance: 1.7438
# Euclidean distance: 0.0281
# Euclidean distance: 0.7252
# Euclidean distance: 2.6855
# Euclidean distance: 3.8577
# Euclidean distance: 1.6641
# Euclidean distance: 0.1572
# Euclidean distance: 1.5539
# Euclidean distance: 1.3842
# Euclidean distance: 0.6388
# Euclidean distance: 1.6190
# Euclidean distance: 1.8624
# Euclidean distance: 2.8869
# Euclidean distance: 0.2838
# Euclidean distance: 1.5725
# Euclidean distance: 1.1514
# Euclidean distance: 1.6156
# Euclidean distance: 1.3512
# Euclidean distance: 0.6357
# Euclidean distance: 0.7031
# Euclidean distance: 1.5907
# Euclidean distance: 1.7028
# Euclidean distance: 1.5973
# Euclidean distance: 1.7790
# Euclidean distance: 1.4800
# Euclidean distance: 0.1661
# Euclidean distance: 0.2425
# Euclidean distance: 1.5408
# Euclidean distance: 0.6447
# Euclidean distance: 0.6380
# Euclidean distance: 3.9764
# Euclidean distance: 2.6596
# Euclidean distance: 1.8271
# Euclidean distance: 1.6586
# Euclidean distance: 1.0587
# Euclidean distance: 2.1981
# Euclidean distance: 1.1852
# Euclidean distance: 1.7678
# Euclidean distance: 1.7193
# Euclidean distance: 1.5929
# Euclidean distance: 3.8170
# Euclidean distance: 3.1995
# Euclidean distance: 0.4002
# Euclidean distance: 1.5025
# Euclidean distance: 1.8231
# Euclidean distance: 2.6235
# Euclidean distance: 1.7352
# Euclidean distance: 1.5007
# Euclidean distance: 1.4752
# Euclidean distance: 0.7268
# Euclidean distance: 1.8427
# Euclidean distance: 3.8167
# Euclidean distance: 1.5063
# Euclidean distance: 1.3470
# All distances: ['1.4126', '1.5307', '1.4917', '2.0526', '0.1768']...
# K nearest neighbor indices: [17 12 22]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 16 ---
# Test point: [ 0.58590018 -1.33745666]
# Euclidean distance: 0.8879
# Euclidean distance: 0.5069
# Euclidean distance: 0.6192
# Euclidean distance: 0.7278
# Euclidean distance: 1.6121
# Euclidean distance: 0.1714
# Euclidean distance: 3.3061
# Euclidean distance: 3.9973
# Euclidean distance: 0.5716
# Euclidean distance: 0.6575
# Euclidean distance: 1.0449
# Euclidean distance: 0.1031
# Euclidean distance: 1.6042
# Euclidean distance: 0.1513
# Euclidean distance: 0.3060
# Euclidean distance: 3.1165
# Euclidean distance: 1.6058
# Euclidean distance: 1.6717
# Euclidean distance: 2.0937
# Euclidean distance: 3.8070
# Euclidean distance: 4.9167
# Euclidean distance: 0.0198
# Euclidean distance: 1.6285
# Euclidean distance: 0.2329
# Euclidean distance: 1.0471
# Euclidean distance: 1.4390
# Euclidean distance: 0.0399
# Euclidean distance: 0.3166
# Euclidean distance: 4.0228
# Euclidean distance: 1.5667
# Euclidean distance: 0.7334
# Euclidean distance: 2.4936
# Euclidean distance: 0.2226
# Euclidean distance: 2.6216
# Euclidean distance: 2.0332
# Euclidean distance: 2.0953
# Euclidean distance: 0.0884
# Euclidean distance: 1.6046
# Euclidean distance: 2.8195
# Euclidean distance: 0.1957
# Euclidean distance: 0.6539
# Euclidean distance: 1.5398
# Euclidean distance: 1.5104
# Euclidean distance: 1.0539
# Euclidean distance: 2.0974
# Euclidean distance: 2.0345
# Euclidean distance: 5.0264
# Euclidean distance: 3.7791
# Euclidean distance: 3.0417
# Euclidean distance: 1.6247
# Euclidean distance: 2.3576
# Euclidean distance: 3.3646
# Euclidean distance: 2.4953
# Euclidean distance: 1.6284
# Euclidean distance: 0.1204
# Euclidean distance: 0.5177
# Euclidean distance: 4.8667
# Euclidean distance: 4.3124
# Euclidean distance: 1.9397
# Euclidean distance: 0.2424
# Euclidean distance: 0.1915
# Euclidean distance: 1.3526
# Euclidean distance: 0.2724
# Euclidean distance: 1.5651
# Euclidean distance: 0.7320
# Euclidean distance: 2.1799
# Euclidean distance: 0.3034
# Euclidean distance: 4.8616
# Euclidean distance: 1.0587
# Euclidean distance: 2.6158
# All distances: ['0.8879', '0.5069', '0.6192', '0.7278', '1.6121']...
# K nearest neighbor indices: [21 26 36]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 17 ---
# Test point: [ 0.37705866 -1.47857623]
# Euclidean distance: 1.1375
# Euclidean distance: 0.7589
# Euclidean distance: 0.8709
# Euclidean distance: 0.4758
# Euclidean distance: 1.6997
# Euclidean distance: 0.3991
# Euclidean distance: 3.5173
# Euclidean distance: 4.2173
# Euclidean distance: 0.8220
# Euclidean distance: 0.9048
# Euclidean distance: 1.2969
# Euclidean distance: 0.2268
# Euclidean distance: 1.6965
# Euclidean distance: 0.1043
# Euclidean distance: 0.5577
# Euclidean distance: 3.3266
# Euclidean distance: 1.8576
# Euclidean distance: 1.7799
# Euclidean distance: 2.2641
# Euclidean distance: 4.0262
# Euclidean distance: 5.1453
# Euclidean distance: 0.2332
# Euclidean distance: 1.7184
# Euclidean distance: 0.4842
# Euclidean distance: 1.2953
# Euclidean distance: 1.4597
# Euclidean distance: 0.2460
# Euclidean distance: 0.1002
# Euclidean distance: 4.2419
# Euclidean distance: 1.6401
# Euclidean distance: 0.9852
# Euclidean distance: 2.6764
# Euclidean distance: 0.4731
# Euclidean distance: 2.8150
# Euclidean distance: 2.1979
# Euclidean distance: 2.2627
# Euclidean distance: 0.2317
# Euclidean distance: 1.8559
# Euclidean distance: 3.0208
# Euclidean distance: 0.0835
# Euclidean distance: 0.9054
# Euclidean distance: 1.6346
# Euclidean distance: 1.5946
# Euclidean distance: 1.3057
# Euclidean distance: 2.2568
# Euclidean distance: 2.1994
# Euclidean distance: 5.2560
# Euclidean distance: 3.9983
# Euclidean distance: 3.2463
# Euclidean distance: 1.8751
# Euclidean distance: 2.5429
# Euclidean distance: 3.5768
# Euclidean distance: 2.6820
# Euclidean distance: 1.8803
# Euclidean distance: 0.3360
# Euclidean distance: 0.7686
# Euclidean distance: 5.0959
# Euclidean distance: 4.5347
# Euclidean distance: 2.0812
# Euclidean distance: 0.4876
# Euclidean distance: 0.1623
# Euclidean distance: 1.1045
# Euclidean distance: 0.0449
# Euclidean distance: 1.4422
# Euclidean distance: 0.9835
# Euclidean distance: 2.3414
# Euclidean distance: 0.0805
# Euclidean distance: 5.0911
# Euclidean distance: 1.3101
# Euclidean distance: 2.8093
# All distances: ['1.1375', '0.7589', '0.8709', '0.4758', '1.6997']...
# K nearest neighbor indices: [62 66 39]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 18 ---
# Test point: [1.93866732 1.89910321]
# Euclidean distance: 2.7233
# Euclidean distance: 3.0951
# Euclidean distance: 2.9869
# Euclidean distance: 4.1427
# Euclidean distance: 2.5119
# Euclidean distance: 3.3376
# Euclidean distance: 0.2104
# Euclidean distance: 0.5319
# Euclidean distance: 3.0023
# Euclidean distance: 2.8996
# Euclidean distance: 2.6880
# Euclidean distance: 3.5968
# Euclidean distance: 2.4864
# Euclidean distance: 3.6452
# Euclidean distance: 3.2699
# Euclidean distance: 0.4011
# Euclidean distance: 2.2694
# Euclidean distance: 2.3475
# Euclidean distance: 1.6187
# Euclidean distance: 0.3471
# Euclidean distance: 1.5169
# Euclidean distance: 3.5270
# Euclidean distance: 2.4890
# Euclidean distance: 3.3022
# Euclidean distance: 2.5675
# Euclidean distance: 2.9802
# Euclidean distance: 3.4944
# Euclidean distance: 3.8107
# Euclidean distance: 0.5458
# Euclidean distance: 2.6217
# Euclidean distance: 2.9501
# Euclidean distance: 1.1928
# Euclidean distance: 3.3470
# Euclidean distance: 0.9906
# Euclidean distance: 1.7075
# Euclidean distance: 1.6390
# Euclidean distance: 3.4937
# Euclidean distance: 2.2342
# Euclidean distance: 0.7461
# Euclidean distance: 3.6952
# Euclidean distance: 2.9531
# Euclidean distance: 2.5041
# Euclidean distance: 2.5824
# Euclidean distance: 2.6561
# Euclidean distance: 1.6993
# Euclidean distance: 1.7053
# Euclidean distance: 1.6360
# Euclidean distance: 0.3229
# Euclidean distance: 0.5146
# Euclidean distance: 2.1748
# Euclidean distance: 1.2850
# Euclidean distance: 0.1467
# Euclidean distance: 1.1565
# Euclidean distance: 2.2666
# Euclidean distance: 3.5061
# Euclidean distance: 3.1290
# Euclidean distance: 1.4775
# Euclidean distance: 0.8580
# Euclidean distance: 1.9481
# Euclidean distance: 3.2735
# Euclidean distance: 3.6981
# Euclidean distance: 4.7744
# Euclidean distance: 3.7147
# Euclidean distance: 3.8421
# Euclidean distance: 2.8881
# Euclidean distance: 1.6218
# Euclidean distance: 3.7937
# Euclidean distance: 1.4780
# Euclidean distance: 2.6285
# Euclidean distance: 0.9949
# All distances: ['2.7233', '3.0951', '2.9869', '4.1427', '2.5119']...
# K nearest neighbor indices: [51  6 47]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 19 ---
# Test point: [0.73902766 0.82180719]
# Euclidean distance: 1.6307
# Euclidean distance: 1.8923
# Euclidean distance: 1.8146
# Euclidean distance: 2.6855
# Euclidean distance: 0.8999
# Euclidean distance: 1.9974
# Euclidean distance: 1.4053
# Euclidean distance: 2.1443
# Euclidean distance: 1.7993
# Euclidean distance: 1.7028
# Euclidean distance: 1.7171
# Euclidean distance: 2.2655
# Euclidean distance: 0.8751
# Euclidean distance: 2.2760
# Euclidean distance: 2.0095
# Euclidean distance: 1.2258
# Euclidean distance: 1.6403
# Euclidean distance: 0.7363
# Euclidean distance: 0.1005
# Euclidean distance: 1.9576
# Euclidean distance: 3.1293
# Euclidean distance: 2.1811
# Euclidean distance: 0.8769
# Euclidean distance: 2.0089
# Euclidean distance: 1.5309
# Euclidean distance: 1.3690
# Euclidean distance: 2.1400
# Euclidean distance: 2.4270
# Euclidean distance: 2.1568
# Euclidean distance: 1.0097
# Euclidean distance: 1.8452
# Euclidean distance: 0.4199
# Euclidean distance: 2.0662
# Euclidean distance: 0.6247
# Euclidean distance: 0.1316
# Euclidean distance: 0.0785
# Euclidean distance: 2.1239
# Euclidean distance: 1.5934
# Euclidean distance: 0.8719
# Euclidean distance: 2.3260
# Euclidean distance: 1.7904
# Euclidean distance: 0.8966
# Euclidean distance: 0.9742
# Euclidean distance: 1.6792
# Euclidean distance: 0.0873
# Euclidean distance: 0.1303
# Euclidean distance: 3.2482
# Euclidean distance: 1.9320
# Euclidean distance: 1.0983
# Euclidean distance: 1.5325
# Euclidean distance: 0.3430
# Euclidean distance: 1.4701
# Euclidean distance: 0.4572
# Euclidean distance: 1.6572
# Euclidean distance: 2.2025
# Euclidean distance: 1.9459
# Euclidean distance: 3.0894
# Euclidean distance: 2.4697
# Euclidean distance: 0.3357
# Euclidean distance: 1.9654
# Euclidean distance: 2.3525
# Euclidean distance: 3.2887
# Euclidean distance: 2.3104
# Euclidean distance: 2.2305
# Euclidean distance: 1.7544
# Euclidean distance: 0.0324
# Euclidean distance: 2.4080
# Euclidean distance: 3.0895
# Euclidean distance: 1.6426
# Euclidean distance: 0.6209
# All distances: ['1.6307', '1.8923', '1.8146', '2.6855', '0.8999']...
# K nearest neighbor indices: [65 35 44]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 20 ---
# Test point: [ 1.61550606 -0.57301231]
# Euclidean distance: 0.4123
# Euclidean distance: 0.7761
# Euclidean distance: 0.6633
# Euclidean distance: 2.0100
# Euclidean distance: 1.7075
# Euclidean distance: 1.1506
# Euclidean distance: 2.3157
# Euclidean distance: 2.9209
# Euclidean distance: 0.7150
# Euclidean distance: 0.6473
# Euclidean distance: 0.2407
# Euclidean distance: 1.3346
# Euclidean distance: 1.6791
# Euclidean distance: 1.4331
# Euclidean distance: 0.9790
# Euclidean distance: 2.1441
# Euclidean distance: 0.3237
# Euclidean distance: 1.6392
# Euclidean distance: 1.5479
# Euclidean distance: 2.7412
# Euclidean distance: 3.7693
# Euclidean distance: 1.3015
# Euclidean distance: 1.7066
# Euclidean distance: 1.0500
# Euclidean distance: 0.2935
# Euclidean distance: 1.8896
# Euclidean distance: 1.2904
# Euclidean distance: 1.5924
# Euclidean distance: 2.9521
# Euclidean distance: 1.7465
# Euclidean distance: 0.5573
# Euclidean distance: 1.7827
# Euclidean distance: 1.0654
# Euclidean distance: 1.8163
# Euclidean distance: 1.5414
# Euclidean distance: 1.5698
# Euclidean distance: 1.3164
# Euclidean distance: 0.3268
# Euclidean distance: 1.9343
# Euclidean distance: 1.4734
# Euclidean distance: 0.6291
# Euclidean distance: 1.6251
# Euclidean distance: 1.6592
# Euclidean distance: 0.2285
# Euclidean distance: 1.6270
# Euclidean distance: 1.5412
# Euclidean distance: 3.8719
# Euclidean distance: 2.7139
# Euclidean distance: 2.1145
# Euclidean distance: 0.3597
# Euclidean distance: 1.6492
# Euclidean distance: 2.3637
# Euclidean distance: 1.7556
# Euclidean distance: 0.3461
# Euclidean distance: 1.2218
# Euclidean distance: 0.7759
# Euclidean distance: 3.7165
# Euclidean distance: 3.2138
# Euclidean distance: 1.6273
# Euclidean distance: 1.0522
# Euclidean distance: 1.4389
# Euclidean distance: 2.6306
# Euclidean distance: 1.5504
# Euclidean distance: 2.4793
# Euclidean distance: 0.5513
# Euclidean distance: 1.6764
# Euclidean distance: 1.5817
# Euclidean distance: 3.7093
# Euclidean distance: 0.2275
# Euclidean distance: 1.8105
# All distances: ['0.4123', '0.7761', '0.6633', '2.0100', '1.7075']...
# K nearest neighbor indices: [68 43 10]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 21 ---
# Test point: [1.45151031 1.38591822]
# Euclidean distance: 2.1286
# Euclidean distance: 2.4783
# Euclidean distance: 2.3765
# Euclidean distance: 3.4660
# Euclidean distance: 1.8065
# Euclidean distance: 2.6863
# Euclidean distance: 0.4983
# Euclidean distance: 1.2388
# Euclidean distance: 2.3834
# Euclidean distance: 2.2801
# Euclidean distance: 2.1292
# Euclidean distance: 2.9508
# Euclidean distance: 1.7805
# Euclidean distance: 2.9891
# Euclidean distance: 2.6397
# Euclidean distance: 0.3174
# Euclidean distance: 1.8036
# Euclidean distance: 1.6417
# Euclidean distance: 0.9113
# Euclidean distance: 1.0503
# Euclidean distance: 2.2226
# Euclidean distance: 2.8762
# Euclidean distance: 1.7839
# Euclidean distance: 2.6632
# Euclidean distance: 1.9835
# Euclidean distance: 2.2739
# Euclidean distance: 2.8409
# Euclidean distance: 3.1520
# Euclidean distance: 1.2534
# Euclidean distance: 1.9162
# Euclidean distance: 2.3587
# Euclidean distance: 0.4928
# Euclidean distance: 2.7122
# Euclidean distance: 0.2843
# Euclidean distance: 1.0003
# Euclidean distance: 0.9321
# Euclidean distance: 2.8361
# Euclidean distance: 1.7615
# Euclidean distance: 0.0393
# Euclidean distance: 3.0395
# Euclidean distance: 2.3446
# Euclidean distance: 1.7970
# Euclidean distance: 1.8755
# Euclidean distance: 2.0941
# Euclidean distance: 0.9951
# Euclidean distance: 0.9980
# Euclidean distance: 2.3412
# Euclidean distance: 1.0244
# Euclidean distance: 0.1946
# Euclidean distance: 1.6968
# Euclidean distance: 0.5775
# Euclidean distance: 0.5631
# Euclidean distance: 0.4516
# Euclidean distance: 1.8078
# Euclidean distance: 2.8669
# Euclidean distance: 2.5186
# Euclidean distance: 2.1819
# Euclidean distance: 1.5653
# Euclidean distance: 1.2441
# Euclidean distance: 2.6300
# Euclidean distance: 3.0490
# Euclidean distance: 4.0921
# Euclidean distance: 3.0497
# Euclidean distance: 3.1358
# Euclidean distance: 2.2864
# Euclidean distance: 0.9204
# Euclidean distance: 3.1343
# Euclidean distance: 2.1817
# Euclidean distance: 2.0625
# Euclidean distance: 0.2883
# All distances: ['2.1286', '2.4783', '2.3765', '3.4660', '1.8065']...
# K nearest neighbor indices: [38 48 33]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 22 ---
# Test point: [1.44169528 1.40932861]
# Euclidean distance: 2.1510
# Euclidean distance: 2.4996
# Euclidean distance: 2.3981
# Euclidean distance: 3.4831
# Euclidean distance: 1.8147
# Euclidean distance: 2.7056
# Euclidean distance: 0.4895
# Euclidean distance: 1.2295
# Euclidean distance: 2.4047
# Euclidean distance: 2.3014
# Euclidean distance: 2.1526
# Euclidean distance: 2.9704
# Euclidean distance: 1.7889
# Euclidean distance: 3.0081
# Euclidean distance: 2.6603
# Euclidean distance: 0.3129
# Euclidean distance: 1.8286
# Euclidean distance: 1.6501
# Euclidean distance: 0.9211
# Euclidean distance: 1.0419
# Euclidean distance: 2.2139
# Euclidean distance: 2.8955
# Euclidean distance: 1.7919
# Euclidean distance: 2.6833
# Euclidean distance: 2.0063
# Euclidean distance: 2.2826
# Euclidean distance: 2.8601
# Euclidean distance: 3.1707
# Euclidean distance: 1.2434
# Euclidean distance: 1.9244
# Euclidean distance: 2.3810
# Euclidean distance: 0.4981
# Euclidean distance: 2.7325
# Euclidean distance: 0.2928
# Euclidean distance: 1.0098
# Euclidean distance: 0.9413
# Euclidean distance: 2.8550
# Euclidean distance: 1.7864
# Euclidean distance: 0.0579
# Euclidean distance: 3.0585
# Euclidean distance: 2.3663
# Euclidean distance: 1.8063
# Euclidean distance: 1.8847
# Euclidean distance: 2.1174
# Euclidean distance: 1.0026
# Euclidean distance: 1.0075
# Euclidean distance: 2.3327
# Euclidean distance: 1.0162
# Euclidean distance: 0.1832
# Euclidean distance: 1.7217
# Euclidean distance: 0.5877
# Euclidean distance: 0.5543
# Euclidean distance: 0.4591
# Euclidean distance: 1.8329
# Euclidean distance: 2.8869
# Euclidean distance: 2.5401
# Euclidean distance: 2.1736
# Euclidean distance: 1.5557
# Euclidean distance: 1.2516
# Euclidean distance: 2.6499
# Euclidean distance: 3.0684
# Euclidean distance: 4.1086
# Euclidean distance: 3.0679
# Euclidean distance: 3.1445
# Euclidean distance: 2.3084
# Euclidean distance: 0.9267
# Euclidean distance: 3.1530
# Euclidean distance: 2.1737
# Euclidean distance: 2.0857
# Euclidean distance: 0.2972
# All distances: ['2.1510', '2.4996', '2.3981', '3.4831', '1.8147']...
# K nearest neighbor indices: [38 48 33]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 23 ---
# Test point: [1.12991576 1.10236134]
# Euclidean distance: 1.8371
# Euclidean distance: 2.1577
# Euclidean distance: 2.0640
# Euclidean distance: 3.0782
# Euclidean distance: 1.3778
# Euclidean distance: 2.3287
# Euclidean distance: 0.9267
# Euclidean distance: 1.6670
# Euclidean distance: 2.0624
# Euclidean distance: 1.9602
# Euclidean distance: 1.8724
# Euclidean distance: 2.5964
# Euclidean distance: 1.3518
# Euclidean distance: 2.6244
# Euclidean distance: 2.3039
# Euclidean distance: 0.7451
# Euclidean distance: 1.6458
# Euclidean distance: 1.2130
# Euclidean distance: 0.4839
# Euclidean distance: 1.4790
# Euclidean distance: 2.6512
# Euclidean distance: 2.5176
# Euclidean distance: 1.3551
# Euclidean distance: 2.3184
# Euclidean distance: 1.7067
# Euclidean distance: 1.8453
# Euclidean distance: 2.4799
# Euclidean distance: 2.7837
# Euclidean distance: 1.6808
# Euclidean distance: 1.4874
# Euclidean distance: 2.0650
# Euclidean distance: 0.0904
# Euclidean distance: 2.3710
# Euclidean distance: 0.1447
# Euclidean distance: 0.5724
# Euclidean distance: 0.5037
# Euclidean distance: 2.4708
# Euclidean distance: 1.5999
# Euclidean distance: 0.3913
# Euclidean distance: 2.6750
# Euclidean distance: 2.0347
# Euclidean distance: 1.3688
# Euclidean distance: 1.4472
# Euclidean distance: 1.8353
# Euclidean distance: 0.5670
# Euclidean distance: 0.5701
# Euclidean distance: 2.7699
# Euclidean distance: 1.4531
# Euclidean distance: 0.6207
# Euclidean distance: 1.5345
# Euclidean distance: 0.1527
# Euclidean distance: 0.9916
# Euclidean distance: 0.0318
# Euclidean distance: 1.6560
# Euclidean distance: 2.5199
# Euclidean distance: 2.2037
# Euclidean distance: 2.6106
# Euclidean distance: 1.9932
# Euclidean distance: 0.8159
# Euclidean distance: 2.2811
# Euclidean distance: 2.6909
# Euclidean distance: 3.6971
# Euclidean distance: 2.6756
# Euclidean distance: 2.7072
# Euclidean distance: 1.9842
# Euclidean distance: 0.4946
# Euclidean distance: 2.7654
# Euclidean distance: 2.6105
# Euclidean distance: 1.8009
# Euclidean distance: 0.1405
# All distances: ['1.8371', '2.1577', '2.0640', '3.0782', '1.3778']...
# K nearest neighbor indices: [52 31 69]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 24 ---
# Test point: [-0.08239154 -0.02861137]
# Euclidean distance: 1.4933
# Euclidean distance: 1.4927
# Euclidean distance: 1.4881
# Euclidean distance: 1.7306
# Euclidean distance: 0.2848
# Euclidean distance: 1.3497
# Euclidean distance: 2.5847
# Euclidean distance: 3.3249
# Euclidean distance: 1.4350
# Euclidean distance: 1.3885
# Euclidean distance: 1.6866
# Euclidean distance: 1.5674
# Euclidean distance: 0.3075
# Euclidean distance: 1.5156
# Euclidean distance: 1.4857
# Euclidean distance: 2.4016
# Euclidean distance: 1.9789
# Euclidean distance: 0.4461
# Euclidean distance: 1.1763
# Euclidean distance: 3.1369
# Euclidean distance: 4.3091
# Euclidean distance: 1.4779
# Euclidean distance: 0.3086
# Euclidean distance: 1.4344
# Euclidean distance: 1.5144
# Euclidean distance: 0.1875
# Euclidean distance: 1.4322
# Euclidean distance: 1.6178
# Euclidean distance: 3.3382
# Euclidean distance: 0.1768
# Euclidean distance: 1.5979
# Euclidean distance: 1.6021
# Euclidean distance: 1.4946
# Euclidean distance: 1.8026
# Euclidean distance: 1.0868
# Euclidean distance: 1.1544
# Euclidean distance: 1.3940
# Euclidean distance: 1.9434
# Euclidean distance: 2.0487
# Euclidean distance: 1.5564
# Euclidean distance: 1.4872
# Euclidean distance: 0.2922
# Euclidean distance: 0.2138
# Euclidean distance: 1.6591
# Euclidean distance: 1.0951
# Euclidean distance: 1.0891
# Euclidean distance: 4.4278
# Euclidean distance: 3.1110
# Euclidean distance: 2.2784
# Euclidean distance: 1.9104
# Euclidean distance: 1.5100
# Euclidean distance: 2.6495
# Euclidean distance: 1.6365
# Euclidean distance: 2.0047
# Euclidean distance: 1.5610
# Euclidean distance: 1.5557
# Euclidean distance: 4.2684
# Euclidean distance: 3.6508
# Euclidean distance: 0.8481
# Euclidean distance: 1.3804
# Euclidean distance: 1.6151
# Euclidean distance: 2.2571
# Euclidean distance: 1.4864
# Euclidean distance: 1.0493
# Euclidean distance: 1.5060
# Euclidean distance: 1.1758
# Euclidean distance: 1.5985
# Euclidean distance: 4.2681
# Euclidean distance: 1.6294
# Euclidean distance: 1.7984
# All distances: ['1.4933', '1.4927', '1.4881', '1.7306', '0.2848']...
# K nearest neighbor indices: [29 25 42]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 25 ---
# Test point: [ 0.88259274 -1.13663628]
# Euclidean distance: 0.5368
# Euclidean distance: 0.1486
# Euclidean distance: 0.2624
# Euclidean distance: 1.0860
# Euclidean distance: 1.5506
# Euclidean distance: 0.2516
# Euclidean distance: 3.0166
# Euclidean distance: 3.6915
# Euclidean distance: 0.2217
# Euclidean distance: 0.3189
# Euclidean distance: 0.6867
# Euclidean distance: 0.4139
# Euclidean distance: 1.5358
# Euclidean distance: 0.5086
# Euclidean distance: 0.0574
# Euclidean distance: 2.8295
# Euclidean distance: 1.2482
# Euclidean distance: 1.5753
# Euclidean distance: 1.8832
# Euclidean distance: 3.5029
# Euclidean distance: 4.5958
# Euclidean distance: 0.3772
# Euclidean distance: 1.5628
# Euclidean distance: 0.1292
# Euclidean distance: 0.6992
# Euclidean distance: 1.4845
# Euclidean distance: 0.3694
# Euclidean distance: 0.6687
# Euclidean distance: 3.7184
# Euclidean distance: 1.5289
# Euclidean distance: 0.3763
# Euclidean distance: 2.2565
# Euclidean distance: 0.1431
# Euclidean distance: 2.3657
# Euclidean distance: 1.8332
# Euclidean distance: 1.8897
# Euclidean distance: 0.4015
# Euclidean distance: 1.2479
# Euclidean distance: 2.5488
# Euclidean distance: 0.5491
# Euclidean distance: 0.2977
# Euclidean distance: 1.4700
# Euclidean distance: 1.4585
# Euclidean distance: 0.6961
# Euclidean distance: 1.9053
# Euclidean distance: 1.8342
# Euclidean distance: 4.7039
# Euclidean distance: 3.4750
# Euclidean distance: 2.7642
# Euclidean distance: 1.2697
# Euclidean distance: 2.1177
# Euclidean distance: 3.0731
# Euclidean distance: 2.2517
# Euclidean distance: 1.2706
# Euclidean distance: 0.3054
# Euclidean distance: 0.1673
# Euclidean distance: 4.5450
# Euclidean distance: 4.0022
# Euclidean distance: 1.7808
# Euclidean distance: 0.1513
# Euclidean distance: 0.5197
# Euclidean distance: 1.7073
# Euclidean distance: 0.6289
# Euclidean distance: 1.7869
# Euclidean distance: 0.3758
# Euclidean distance: 1.9828
# Euclidean distance: 0.6575
# Euclidean distance: 4.5394
# Euclidean distance: 0.7022
# Euclidean distance: 2.3598
# All distances: ['0.5368', '0.1486', '0.2624', '1.0860', '1.5506']...
# K nearest neighbor indices: [14 23 32]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 26 ---
# Test point: [ 1.00183089 -1.02646717]
# Euclidean distance: 0.3758
# Euclidean distance: 0.0254
# Euclidean distance: 0.1001
# Euclidean distance: 1.2470
# Euclidean distance: 1.5249
# Euclidean distance: 0.3963
# Euclidean distance: 2.8763
# Euclidean distance: 3.5440
# Euclidean distance: 0.0705
# Euclidean distance: 0.1738
# Euclidean distance: 0.5263
# Euclidean distance: 0.5759
# Euclidean distance: 1.5072
# Euclidean distance: 0.6702
# Euclidean distance: 0.2185
# Euclidean distance: 2.6905
# Euclidean distance: 1.0865
# Euclidean distance: 1.5328
# Euclidean distance: 1.7824
# Euclidean distance: 3.3563
# Euclidean distance: 4.4424
# Euclidean distance: 0.5385
# Euclidean distance: 1.5349
# Euclidean distance: 0.2872
# Euclidean distance: 0.5390
# Euclidean distance: 1.5089
# Euclidean distance: 0.5281
# Euclidean distance: 0.8310
# Euclidean distance: 3.5715
# Euclidean distance: 1.5147
# Euclidean distance: 0.2233
# Euclidean distance: 2.1412
# Euclidean distance: 0.3050
# Euclidean distance: 2.2413
# Euclidean distance: 1.7379
# Euclidean distance: 1.7913
# Euclidean distance: 0.5566
# Euclidean distance: 1.0857
# Euclidean distance: 2.4173
# Euclidean distance: 0.7113
# Euclidean distance: 0.1354
# Euclidean distance: 1.4419
# Euclidean distance: 1.4391
# Euclidean distance: 0.5345
# Euclidean distance: 1.8132
# Euclidean distance: 1.7388
# Euclidean distance: 4.5499
# Euclidean distance: 3.3284
# Euclidean distance: 2.6294
# Euclidean distance: 1.1074
# Euclidean distance: 2.0017
# Euclidean distance: 2.9319
# Euclidean distance: 2.1333
# Euclidean distance: 1.1091
# Euclidean distance: 0.4661
# Euclidean distance: 0.0855
# Euclidean distance: 4.3913
# Euclidean distance: 3.8529
# Euclidean distance: 1.7056
# Euclidean distance: 0.2947
# Euclidean distance: 0.6815
# Euclidean distance: 1.8696
# Euclidean distance: 0.7882
# Euclidean distance: 1.8831
# Euclidean distance: 0.2135
# Euclidean distance: 1.8877
# Euclidean distance: 0.8197
# Euclidean distance: 4.3855
# Euclidean distance: 0.5399
# Euclidean distance: 2.2354
# All distances: ['0.3758', '0.0254', '0.1001', '1.2470', '1.5249']...
# K nearest neighbor indices: [ 1  8 55]
# K nearest neighbor labels: [0, 0, 0]
# Predicted label: 0
#
# --- Predicting sample 27 ---
# Test point: [1.68538712 1.63306798]
# Euclidean distance: 2.4073
# Euclidean distance: 2.7698
# Euclidean distance: 2.6643
# Euclidean distance: 3.7902
# Euclidean distance: 2.1455
# Euclidean distance: 2.9965
# Euclidean distance: 0.1588
# Euclidean distance: 0.8988
# Euclidean distance: 2.6758
# Euclidean distance: 2.5726
# Euclidean distance: 2.3884
# Euclidean distance: 3.2585
# Euclidean distance: 2.1198
# Euclidean distance: 3.3022
# Euclidean distance: 2.9386
# Euclidean distance: 0.0689
# Euclidean distance: 2.0104
# Euclidean distance: 1.9809
# Euclidean distance: 1.2514
# Euclidean distance: 0.7111
# Euclidean distance: 1.8831
# Euclidean distance: 3.1863
# Euclidean distance: 2.1227
# Euclidean distance: 2.9668
# Euclidean distance: 2.2558
# Euclidean distance: 2.6134
# Euclidean distance: 3.1525
# Euclidean distance: 3.4666
# Euclidean distance: 0.9131
# Euclidean distance: 2.2552
# Euclidean distance: 2.6362
# Euclidean distance: 0.8278
# Euclidean distance: 3.0136
# Euclidean distance: 0.6235
# Euclidean distance: 1.3403
# Euclidean distance: 1.2719
# Euclidean distance: 3.1498
# Euclidean distance: 1.9717
# Euclidean distance: 0.3789
# Euclidean distance: 3.3524
# Euclidean distance: 2.6313
# Euclidean distance: 2.1370
# Euclidean distance: 2.2154
# Euclidean distance: 2.3549
# Euclidean distance: 1.3333
# Euclidean distance: 1.3381
# Euclidean distance: 2.0019
# Euclidean distance: 0.6856
# Euclidean distance: 0.1483
# Euclidean distance: 1.9093
# Euclidean distance: 0.9177
# Euclidean distance: 0.2236
# Euclidean distance: 0.7899
# Euclidean distance: 2.0109
# Euclidean distance: 3.1709
# Euclidean distance: 2.8067
# Euclidean distance: 1.8429
# Euclidean distance: 1.2252
# Euclidean distance: 1.5822
# Euclidean distance: 2.9360
# Euclidean distance: 3.3584
# Euclidean distance: 4.4194
# Euclidean distance: 3.3675
# Euclidean distance: 3.4753
# Euclidean distance: 2.5693
# Euclidean distance: 1.2568
# Euclidean distance: 3.4492
# Euclidean distance: 1.8430
# Euclidean distance: 2.3253
# Euclidean distance: 0.6278
# All distances: ['2.4073', '2.7698', '2.6643', '3.7902', '2.1455']...
# K nearest neighbor indices: [15 48  6]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 28 ---
# Test point: [1.23332293 1.23933572]
# Euclidean distance: 1.9710
# Euclidean distance: 2.3024
# Euclidean distance: 2.2058
# Euclidean distance: 3.2440
# Euclidean distance: 1.5461
# Euclidean distance: 2.4856
# Euclidean distance: 0.7583
# Euclidean distance: 1.4977
# Euclidean distance: 2.2071
# Euclidean distance: 2.1043
# Euclidean distance: 1.9939
# Euclidean distance: 2.7526
# Euclidean distance: 1.5206
# Euclidean distance: 2.7837
# Euclidean distance: 2.4539
# Euclidean distance: 0.5802
# Euclidean distance: 1.7288
# Euclidean distance: 1.3817
# Euclidean distance: 0.6550
# Euclidean distance: 1.3106
# Euclidean distance: 2.4825
# Euclidean distance: 2.6750
# Euclidean distance: 1.5233
# Euclidean distance: 2.4713
# Euclidean distance: 1.8349
# Euclidean distance: 2.0144
# Euclidean distance: 2.6380
# Euclidean distance: 2.9441
# Euclidean distance: 1.5110
# Euclidean distance: 1.6559
# Euclidean distance: 2.2003
# Euclidean distance: 0.2299
# Euclidean distance: 2.5228
# Euclidean distance: 0.0366
# Euclidean distance: 0.7430
# Euclidean distance: 0.6739
# Euclidean distance: 2.6302
# Euclidean distance: 1.6841
# Euclidean distance: 0.2276
# Euclidean distance: 2.8342
# Euclidean distance: 2.1756
# Euclidean distance: 1.5388
# Euclidean distance: 1.6171
# Euclidean distance: 1.9574
# Euclidean distance: 0.7338
# Euclidean distance: 0.7408
# Euclidean distance: 2.6013
# Euclidean distance: 1.2850
# Euclidean distance: 0.4514
# Euclidean distance: 1.6185
# Euclidean distance: 0.3242
# Euclidean distance: 0.8231
# Euclidean distance: 0.1907
# Euclidean distance: 1.7367
# Euclidean distance: 2.6737
# Euclidean distance: 2.3466
# Euclidean distance: 2.4424
# Euclidean distance: 1.8236
# Euclidean distance: 0.9827
# Euclidean distance: 2.4352
# Euclidean distance: 2.8483
# Euclidean distance: 3.8648
# Euclidean distance: 2.8376
# Euclidean distance: 2.8762
# Euclidean distance: 2.1223
# Euclidean distance: 0.6579
# Euclidean distance: 2.9260
# Euclidean distance: 2.4425
# Euclidean distance: 1.9239
# Euclidean distance: 0.0425
# All distances: ['1.9710', '2.3024', '2.2058', '3.2440', '1.5461']...
# K nearest neighbor indices: [33 69 52]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 29 ---
# Test point: [1.42586898 1.39002959]
# Euclidean distance: 2.1303
# Euclidean distance: 2.4778
# Euclidean distance: 2.3767
# Euclidean distance: 3.4590
# Euclidean distance: 1.7900
# Euclidean distance: 2.6825
# Euclidean distance: 0.5142
# Euclidean distance: 1.2543
# Euclidean distance: 2.3829
# Euclidean distance: 2.2796
# Euclidean distance: 2.1333
# Euclidean distance: 2.9475
# Euclidean distance: 1.7642
# Euclidean distance: 2.9847
# Euclidean distance: 2.6380
# Euclidean distance: 0.3364
# Euclidean distance: 1.8136
# Euclidean distance: 1.6254
# Euclidean distance: 0.8962
# Euclidean distance: 1.0665
# Euclidean distance: 2.2386
# Euclidean distance: 2.8724
# Euclidean distance: 1.7673
# Euclidean distance: 2.6607
# Euclidean distance: 1.9861
# Euclidean distance: 2.2579
# Euclidean distance: 2.8369
# Euclidean distance: 3.1473
# Euclidean distance: 1.2682
# Euclidean distance: 1.8997
# Euclidean distance: 2.3603
# Euclidean distance: 0.4740
# Euclidean distance: 2.7100
# Euclidean distance: 0.2680
# Euclidean distance: 0.9850
# Euclidean distance: 0.9164
# Euclidean distance: 2.8316
# Euclidean distance: 1.7712
# Euclidean distance: 0.0379
# Euclidean distance: 3.0352
# Euclidean distance: 2.3450
# Euclidean distance: 1.7815
# Euclidean distance: 1.8599
# Euclidean distance: 2.0981
# Euclidean distance: 0.9780
# Euclidean distance: 0.9827
# Euclidean distance: 2.3574
# Euclidean distance: 1.0408
# Euclidean distance: 0.2081
# Euclidean distance: 1.7064
# Euclidean distance: 0.5628
# Euclidean distance: 0.5790
# Euclidean distance: 0.4345
# Euclidean distance: 1.8182
# Euclidean distance: 2.8642
# Euclidean distance: 2.5186
# Euclidean distance: 2.1983
# Euclidean distance: 1.5805
# Euclidean distance: 1.2270
# Euclidean distance: 2.6271
# Euclidean distance: 3.0453
# Euclidean distance: 4.0842
# Euclidean distance: 3.0442
# Euclidean distance: 3.1198
# Euclidean distance: 2.2874
# Euclidean distance: 0.9024
# Euclidean distance: 3.1295
# Euclidean distance: 2.1983
# Euclidean distance: 2.0663
# Euclidean distance: 0.2723
# All distances: ['2.1303', '2.4778', '2.3767', '3.4590', '1.7900']...
# K nearest neighbor indices: [38 48 33]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# --- Predicting sample 30 ---
# Test point: [-0.21198653 -0.20665158]
# Euclidean distance: 1.5393
# Euclidean distance: 1.4813
# Euclidean distance: 1.4939
# Euclidean distance: 1.5643
# Euclidean distance: 0.5049
# Euclidean distance: 1.2839
# Euclidean distance: 2.8012
# Euclidean distance: 3.5416
# Euclidean distance: 1.4356
# Euclidean distance: 1.4040
# Euclidean distance: 1.7421
# Euclidean distance: 1.4765
# Euclidean distance: 0.5269
# Euclidean distance: 1.4098
# Euclidean distance: 1.4443
# Euclidean distance: 2.6172
# Euclidean distance: 2.0853
# Euclidean distance: 0.6651
# Euclidean distance: 1.3918
# Euclidean distance: 3.3532
# Euclidean distance: 4.5254
# Euclidean distance: 1.3897
# Euclidean distance: 0.5288
# Euclidean distance: 1.3830
# Euclidean distance: 1.5827
# Euclidean distance: 0.0590
# Euclidean distance: 1.3450
# Euclidean distance: 1.4946
# Euclidean distance: 3.5554
# Euclidean distance: 0.3968
# Euclidean distance: 1.6143
# Euclidean distance: 1.8202
# Euclidean distance: 1.4406
# Euclidean distance: 2.0193
# Euclidean distance: 1.3026
# Euclidean distance: 1.3709
# Euclidean distance: 1.3025
# Euclidean distance: 2.0530
# Euclidean distance: 2.2649
# Euclidean distance: 1.4464
# Euclidean distance: 1.4982
# Euclidean distance: 0.5059
# Euclidean distance: 0.4275
# Euclidean distance: 1.7180
# Euclidean distance: 1.3135
# Euclidean distance: 1.3049
# Euclidean distance: 4.6439
# Euclidean distance: 3.3271
# Euclidean distance: 2.4953
# Euclidean distance: 2.0255
# Euclidean distance: 1.7258
# Euclidean distance: 2.8660
# Euclidean distance: 1.8537
# Euclidean distance: 2.1117
# Euclidean distance: 1.4853
# Euclidean distance: 1.5426
# Euclidean distance: 4.4843
# Euclidean distance: 3.8678
# Euclidean distance: 1.0673
# Euclidean distance: 1.3296
# Euclidean distance: 1.5117
# Euclidean distance: 2.0652
# Euclidean distance: 1.3637
# Euclidean distance: 0.8348
# Euclidean distance: 1.5279
# Euclidean distance: 1.3949
# Euclidean distance: 1.4759
# Euclidean distance: 4.4838
# Euclidean distance: 1.6912
# Euclidean distance: 2.0150
# All distances: ['1.5393', '1.4813', '1.4939', '1.5643', '0.5049']...
# K nearest neighbor indices: [25 29 42]
# K nearest neighbor labels: [1, 1, 1]
# Predicted label: 1
#
# 准确率: 1.0000
